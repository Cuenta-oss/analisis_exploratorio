# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly

# %%
data_2010_2017 = pd.read_csv("df_cordoba_2010_2017.csv")
data_2018_2021 = pd.read_csv("df_cordoba_2018_2021.csv")
# Out:
# C:\Users\afg11\AppData\Local\Temp\ipykernel_15668\3079377337.py:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_2010_2017 = pd.read_csv("df_cordoba_2010_2017.csv")
# C:\Users\afg11\AppData\Local\Temp\ipykernel_15668\3079377337.py:2: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_2018_2021 = pd.read_csv("df_cordoba_2018_2021.csv")

# %%
data_2010_2017.describe().T
# Out:
#                           count          mean           std           min  \
# ANNO_INF               981524.0  2.013509e+03  2.279954e+00  2.010000e+03
# COD_DANE_DEPARTAMENTO  981524.0  2.300000e+01  0.000000e+00  2.300000e+01
# COD_SECRETARIA         981524.0  3.781483e+03  8.255520e-01  3.781000e+03
# COD_DANE_MUNICIPIO     981524.0  2.340351e+04  2.899070e+02  2.300100e+04
# CODIGO_DANE            981524.0  2.043688e+11  5.964768e+10  1.230010e+11
# COD_SECTOR             981524.0  1.001080e+03  2.708086e-01  1.001000e+03
# COD_CALENDARIO         940222.0  5.200035e+01  1.867438e-02  5.200000e+01
# CODIGO_DANE_SEDE       981524.0  2.078754e+11  6.382217e+10  1.230010e+11
# COD_ZONA               981524.0  1.004652e+03  4.764935e-01  1.004000e+03
# COD_TIPO_JORNADA       981524.0  2.535764e+00  1.072181e+00  1.000000e+00
# COD_GRADO              981524.0  6.635365e+00  7.962822e+00 -3.000000e+00
# COD_METODOLOGIA        981524.0  2.968384e+00  5.369776e+00  1.000000e+00
# COD_CARACTER           940222.0  7.799966e-02  2.842663e-01  0.000000e+00
# COD_ESPECIALIDAD       940222.0  3.856844e-01  1.412753e+00  0.000000e+00
# EDAD                   981524.0  1.222096e+01  7.561390e+00  0.000000e+00
# COD_GRUPO_ETNICO       981524.0  1.819915e-01  5.507343e-01  0.000000e+00
# COD_SECTOR_CONPES      981524.0  1.341982e+00  8.211961e-01  1.000000e+00
# TOTAL_MATRICULA        981524.0  3.634074e+00  5.962490e+00  0.000000e+00
#
#                                 25%           50%           75%           max
# ANNO_INF               2.012000e+03  2.014000e+03  2.015000e+03  2.017000e+03
# COD_DANE_DEPARTAMENTO  2.300000e+01  2.300000e+01  2.300000e+01  2.300000e+01
# COD_SECRETARIA         3.781000e+03  3.781000e+03  3.782000e+03  3.784000e+03
# COD_DANE_MUNICIPIO     2.309000e+04  2.346600e+04  2.367000e+04  2.385500e+04
# CODIGO_DANE            1.236720e+11  2.234170e+11  2.236700e+11  8.230010e+11
# COD_SECTOR             1.001000e+03  1.001000e+03  1.001000e+03  1.002000e+03
# COD_CALENDARIO         5.200000e+01  5.200000e+01  5.200000e+01  5.300000e+01
# CODIGO_DANE_SEDE       1.238070e+11  2.234170e+11  2.236700e+11  8.956000e+11
# COD_ZONA               1.004000e+03  1.005000e+03  1.005000e+03  1.005000e+03
# COD_TIPO_JORNADA       2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# COD_GRADO              2.000000e+00  4.000000e+00  8.000000e+00  9.900000e+01
# COD_METODOLOGIA        1.000000e+00  1.000000e+00  2.000000e+00  3.000000e+01
# COD_CARACTER           0.000000e+00  0.000000e+00  0.000000e+00  3.000000e+00
# COD_ESPECIALIDAD       0.000000e+00  0.000000e+00  0.000000e+00  1.600000e+01
# EDAD                   8.000000e+00  1.100000e+01  1.500000e+01  9.800000e+01
# COD_GRUPO_ETNICO       0.000000e+00  0.000000e+00  0.000000e+00  7.000000e+00
# COD_SECTOR_CONPES      1.000000e+00  1.000000e+00  1.000000e+00  4.000000e+00
# TOTAL_MATRICULA        1.000000e+00  2.000000e+00  4.000000e+00  9.670000e+02

# %%
# Unimos nuestros datasets para trabajar con uno solo archivo
data_2010_2021 = pd.concat([data_2010_2017, data_2018_2021])

# %%
data_2010_2021.head().T
# Out:
#                                             0                      1  \
# ANNO_INF                                 2017                   2017
# COD_DANE_DEPARTAMENTO                      23                     23
# DEPARTAMENTO                          Córdoba                Córdoba
# COD_SECRETARIA                           3783                   3783
# SECRETARIA                             Lorica                 Lorica
# COD_DANE_MUNICIPIO                      23417                  23417
# MUNICIPIO                              Lorica                 Lorica
# CODIGO_DANE                      223417002072           223417001351
# NOMBRE_ESTABLECIMIENTO            IE EL RODEO        IE SAN ANTERITO
# COD_SECTOR                               1001                   1001
# SECTOR                                OFICIAL                OFICIAL
# COD_CALENDARIO                           52.0                   52.0
# CALENDARIO                                  A                      A
# CODIGO_DANE_SEDE                 223417001513           223417002978
# NOMBRE_SEDE                          LA BUENA             LA ENVIDIA
# COD_ZONA                                 1005                   1005
# ZONA                                    Rural                  Rural
# COD_TIPO_JORNADA                            2                      2
# TIPO_JORNADA                           Mañana                 Mañana
# COD_GRADO                                 4.0                    4.0
# GRADO                                  Cuarto                 Cuarto
# COD_METODOLOGIA                             1                      1
# METODOLOGIA             Educación tradicional  Educación tradicional
# COD_CARACTER                              0.0                    0.0
# CARACTER                            No Aplica              No Aplica
# COD_ESPECIALIDAD                          0.0                    0.0
# ESPECIALIDAD                        No aplica              No aplica
# EDAD                                        8                      8
# COD_GENERO                                  F                      F
# GENERO                               Femenino               Femenino
# COD_GRUPO_ETNICO                            0                      0
# GRUPO_ETNICO                        No aplica              No aplica
# COD_SECTOR_CONPES                           1                      1
# SECTOR_CONPES                         OFICIAL                OFICIAL
# TOTAL_MATRICULA                             3                      1
# CODIGO_GRADO                              NaN                    NaN
#
#                                             2                      3  \
# ANNO_INF                                 2017                   2017
# COD_DANE_DEPARTAMENTO                      23                     23
# DEPARTAMENTO                          Córdoba                Córdoba
# COD_SECRETARIA                           3783                   3783
# SECRETARIA                             Lorica                 Lorica
# COD_DANE_MUNICIPIO                      23417                  23417
# MUNICIPIO                              Lorica                 Lorica
# CODIGO_DANE                      223417002111           223417002111
# NOMBRE_ESTABLECIMIENTO           IE EL CARITO           IE EL CARITO
# COD_SECTOR                               1001                   1001
# SECTOR                                OFICIAL                OFICIAL
# COD_CALENDARIO                           52.0                   52.0
# CALENDARIO                                  A                      A
# CODIGO_DANE_SEDE                 223417000941           223417000941
# NOMBRE_SEDE                         EL CARITO              EL CARITO
# COD_ZONA                                 1005                   1005
# ZONA                                    Rural                  Rural
# COD_TIPO_JORNADA                            3                      3
# TIPO_JORNADA                            Tarde                  Tarde
# COD_GRADO                                 5.0                    5.0
# GRADO                                  Quinto                 Quinto
# COD_METODOLOGIA                             1                      1
# METODOLOGIA             Educación tradicional  Educación tradicional
# COD_CARACTER                              0.0                    0.0
# CARACTER                            No Aplica              No Aplica
# COD_ESPECIALIDAD                          0.0                    0.0
# ESPECIALIDAD                        No aplica              No aplica
# EDAD                                        9                      9
# COD_GENERO                                  F                      M
# GENERO                               Femenino              Masculino
# COD_GRUPO_ETNICO                            0                      0
# GRUPO_ETNICO                        No aplica              No aplica
# COD_SECTOR_CONPES                           1                      1
# SECTOR_CONPES                         OFICIAL                OFICIAL
# TOTAL_MATRICULA                             3                      2
# CODIGO_GRADO                              NaN                    NaN
#
#                                             4
# ANNO_INF                                 2017
# COD_DANE_DEPARTAMENTO                      23
# DEPARTAMENTO                          Córdoba
# COD_SECRETARIA                           3783
# SECRETARIA                             Lorica
# COD_DANE_MUNICIPIO                      23417
# MUNICIPIO                              Lorica
# CODIGO_DANE                      123417001411
# NOMBRE_ESTABLECIMIENTO          IE SANTA CRUZ
# COD_SECTOR                               1001
# SECTOR                                OFICIAL
# COD_CALENDARIO                           52.0
# CALENDARIO                                  A
# CODIGO_DANE_SEDE                 123417001411
# NOMBRE_SEDE                     IE SANTA CRUZ
# COD_ZONA                                 1004
# ZONA                                   Urbana
# COD_TIPO_JORNADA                            3
# TIPO_JORNADA                            Tarde
# COD_GRADO                                 5.0
# GRADO                                  Quinto
# COD_METODOLOGIA                             1
# METODOLOGIA             Educación tradicional
# COD_CARACTER                              0.0
# CARACTER                            No Aplica
# COD_ESPECIALIDAD                          0.0
# ESPECIALIDAD                        No aplica
# EDAD                                       12
# COD_GENERO                                  M
# GENERO                              Masculino
# COD_GRUPO_ETNICO                            0
# GRUPO_ETNICO                        No aplica
# COD_SECTOR_CONPES                           1
# SECTOR_CONPES                         OFICIAL
# TOTAL_MATRICULA                             3
# CODIGO_GRADO                              NaN

# %%
data_2010_2021.describe()
# Out:
#            ANNO_INF  COD_DANE_DEPARTAMENTO  COD_SECRETARIA  \
# count  1.425959e+06              1425959.0    1.425959e+06
# mean   2.015362e+03                   23.0    3.781477e+03
# std    3.398847e+00                    0.0    8.291172e-01
# min    2.010000e+03                   23.0    3.781000e+03
# 25%    2.012000e+03                   23.0    3.781000e+03
# 50%    2.015000e+03                   23.0    3.781000e+03
# 75%    2.018000e+03                   23.0    3.782000e+03
# max    2.021000e+03                   23.0    3.784000e+03
#
#        COD_DANE_MUNICIPIO   CODIGO_DANE    COD_SECTOR  COD_CALENDARIO  \
# count        1.425959e+06  1.425959e+06  1.425959e+06    1.384657e+06
# mean         2.340792e+04  2.062407e+11  1.001086e+03    5.200056e+01
# std          2.891797e+02  6.020025e+10  2.798711e-01    2.357510e-02
# min          2.300100e+04  1.230010e+11  1.001000e+03    5.200000e+01
# 25%          2.309000e+04  1.236860e+11  1.001000e+03    5.200000e+01
# 50%          2.346600e+04  2.234170e+11  1.001000e+03    5.200000e+01
# 75%          2.367000e+04  2.236700e+11  1.001000e+03    5.200000e+01
# max          2.385500e+04  8.230010e+11  1.002000e+03    5.300000e+01
#
#        CODIGO_DANE_SEDE      COD_ZONA  COD_TIPO_JORNADA      COD_GRADO  \
# count      1.425959e+06  1.425959e+06      1.425959e+06  981524.000000
# mean       2.077965e+11  1.004651e+03      2.734315e+00       6.635365
# std        6.263321e+10  4.765715e-01      1.320394e+00       7.962822
# min        1.230010e+11  1.004000e+03      1.000000e+00      -3.000000
# 25%        1.238070e+11  1.004000e+03      2.000000e+00       2.000000
# 50%        2.234170e+11  1.005000e+03      2.000000e+00       4.000000
# 75%        2.236700e+11  1.005000e+03      3.000000e+00       8.000000
# max        8.956000e+11  1.005000e+03      6.000000e+00      99.000000
#
#        COD_METODOLOGIA  COD_CARACTER  COD_ESPECIALIDAD          EDAD  \
# count     1.425959e+06  1.384657e+06      1.384657e+06  1.425959e+06
# mean      2.890793e+00  8.327550e-02      4.126769e-01  1.214608e+01
# std       5.457206e+00  2.923737e-01      1.453940e+00  7.516526e+00
# min       1.000000e+00  0.000000e+00      0.000000e+00  0.000000e+00
# 25%       1.000000e+00  0.000000e+00      0.000000e+00  8.000000e+00
# 50%       1.000000e+00  0.000000e+00      0.000000e+00  1.100000e+01
# 75%       2.000000e+00  0.000000e+00      0.000000e+00  1.500000e+01
# max       4.400000e+01  3.000000e+00      1.600000e+01  9.800000e+01
#
#        COD_GRUPO_ETNICO  COD_SECTOR_CONPES  TOTAL_MATRICULA   CODIGO_GRADO
# count      1.425959e+06       1.425959e+06     1.425959e+06  444435.000000
# mean       5.657952e+00       1.345081e+00     3.667568e+00       6.230063
# std        2.628458e+01       8.439783e-01     5.909864e+00       7.114362
# min        0.000000e+00       1.000000e+00     0.000000e+00      -2.000000
# 25%        0.000000e+00       1.000000e+00     1.000000e+00       2.000000
# 50%        0.000000e+00       1.000000e+00     2.000000e+00       5.000000
# 75%        0.000000e+00       1.000000e+00     4.000000e+00       8.000000
# max        9.990000e+02       4.000000e+00     9.670000e+02      99.000000

# %%
data_2010_2021.dtypes
# Out:
# ANNO_INF                    int64
# COD_DANE_DEPARTAMENTO       int64
# DEPARTAMENTO               object
# COD_SECRETARIA              int64
# SECRETARIA                 object
# COD_DANE_MUNICIPIO          int64
# MUNICIPIO                  object
# CODIGO_DANE                 int64
# NOMBRE_ESTABLECIMIENTO     object
# COD_SECTOR                  int64
# SECTOR                     object
# COD_CALENDARIO            float64
# CALENDARIO                 object
# CODIGO_DANE_SEDE            int64
# NOMBRE_SEDE                object
# COD_ZONA                    int64
# ZONA                       object
# COD_TIPO_JORNADA            int64
# TIPO_JORNADA               object
# COD_GRADO                 float64
# GRADO                      object
# COD_METODOLOGIA             int64
# METODOLOGIA                object
# COD_CARACTER              float64
# CARACTER                   object
# COD_ESPECIALIDAD          float64
# ESPECIALIDAD               object
# EDAD                        int64
# COD_GENERO                 object
# GENERO                     object
# COD_GRUPO_ETNICO            int64
# GRUPO_ETNICO               object
# COD_SECTOR_CONPES           int64
# SECTOR_CONPES              object
# TOTAL_MATRICULA             int64
# CODIGO_GRADO              float64
# dtype: object

# %%
data_2010_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1425959 entries, 0 to 444434
# Data columns (total 36 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   ANNO_INF                1425959 non-null  int64
#  1   COD_DANE_DEPARTAMENTO   1425959 non-null  int64
#  2   DEPARTAMENTO            1425959 non-null  object
#  3   COD_SECRETARIA          1425959 non-null  int64
#  4   SECRETARIA              1425959 non-null  object
#  5   COD_DANE_MUNICIPIO      1425959 non-null  int64
#  6   MUNICIPIO               1425959 non-null  object
#  7   CODIGO_DANE             1425959 non-null  int64
#  8   NOMBRE_ESTABLECIMIENTO  1403982 non-null  object
#  9   COD_SECTOR              1425959 non-null  int64
#  10  SECTOR                  1425959 non-null  object
#  11  COD_CALENDARIO          1384657 non-null  float64
#  12  CALENDARIO              1384657 non-null  object
#  13  CODIGO_DANE_SEDE        1425959 non-null  int64
#  14  NOMBRE_SEDE             1277065 non-null  object
#  15  COD_ZONA                1425959 non-null  int64
#  16  ZONA                    1425959 non-null  object
#  17  COD_TIPO_JORNADA        1425959 non-null  int64
#  18  TIPO_JORNADA            1425959 non-null  object
#  19  COD_GRADO               981524 non-null   float64
#  20  GRADO                   1425959 non-null  object
#  21  COD_METODOLOGIA         1425959 non-null  int64
#  22  METODOLOGIA             1418188 non-null  object
#  23  COD_CARACTER            1384657 non-null  float64
#  24  CARACTER                1384657 non-null  object
#  25  COD_ESPECIALIDAD        1384657 non-null  float64
#  26  ESPECIALIDAD            1384657 non-null  object
#  27  EDAD                    1425959 non-null  int64
#  28  COD_GENERO              1425959 non-null  object
#  29  GENERO                  1425959 non-null  object
#  30  COD_GRUPO_ETNICO        1425959 non-null  int64
#  31  GRUPO_ETNICO            1367687 non-null  object
#  32  COD_SECTOR_CONPES       1425959 non-null  int64
#  33  SECTOR_CONPES           1425959 non-null  object
#  34  TOTAL_MATRICULA         1425959 non-null  int64
#  35  CODIGO_GRADO            444435 non-null   float64
# dtypes: float64(5), int64(14), object(17)
# memory usage: 402.5+ MB

# %%
# Borramos columnas que para este caso no se van a usar porque resultan irrelevantes
data_2010_2021 = data_2010_2021.drop(["COD_DANE_DEPARTAMENTO",
"COD_SECRETARIA",	
"COD_DANE_MUNICIPIO",
"CODIGO_DANE",
"COD_SECTOR",
"COD_CALENDARIO",
"CODIGO_DANE_SEDE",
"COD_ZONA",
"COD_TIPO_JORNADA",
"CODIGO_GRADO",
"COD_METODOLOGIA",
"COD_CARACTER",
"COD_ESPECIALIDAD",
"GENERO",
"COD_GRUPO_ETNICO",
"COD_SECTOR_CONPES",
"COD_SECTOR_CONPES", "COD_GRADO"], axis=1)

# %%
data_2010_2021.describe(include="all")
# Out:
#             ANNO_INF DEPARTAMENTO SECRETARIA MUNICIPIO  \
# count   1.425959e+06      1425959    1425959   1425959
# unique           NaN            2          8        60
# top              NaN      Córdoba    Córdoba  Montería
# freq             NaN       981524     672591    191385
# mean    2.015362e+03          NaN        NaN       NaN
# std     3.398847e+00          NaN        NaN       NaN
# min     2.010000e+03          NaN        NaN       NaN
# 25%     2.012000e+03          NaN        NaN       NaN
# 50%     2.015000e+03          NaN        NaN       NaN
# 75%     2.018000e+03          NaN        NaN       NaN
# max     2.021000e+03          NaN        NaN       NaN
#
#               NOMBRE_ESTABLECIMIENTO   SECTOR CALENDARIO  \
# count                        1403982  1425959    1384657
# unique                          1269        2          2
# top     INST. EDUC. JULIO C. MIRANDA  OFICIAL          A
# freq                            8447  1303802    1383887
# mean                             NaN      NaN        NaN
# std                              NaN      NaN        NaN
# min                              NaN      NaN        NaN
# 25%                              NaN      NaN        NaN
# 50%                              NaN      NaN        NaN
# 75%                              NaN      NaN        NaN
# max                              NaN      NaN        NaN
#
#                        NOMBRE_SEDE     ZONA TIPO_JORNADA    GRADO  \
# count                      1277065  1425959      1425959  1425959
# unique                        2714        2            6       25
# top     COLEGIO JOSÉ ANTONIO GALÁN    Rural       Mañana  Tercero
# freq                          4963   928671       945564   155131
# mean                           NaN      NaN          NaN      NaN
# std                            NaN      NaN          NaN      NaN
# min                            NaN      NaN          NaN      NaN
# 25%                            NaN      NaN          NaN      NaN
# 50%                            NaN      NaN          NaN      NaN
# 75%                            NaN      NaN          NaN      NaN
# max                            NaN      NaN          NaN      NaN
#
#                   METODOLOGIA   CARACTER ESPECIALIDAD          EDAD  \
# count                 1418188    1384657      1384657  1.425959e+06
# unique                     22          4            8           NaN
# top     Educación tradicional  No Aplica    No aplica           NaN
# freq                  1008887    1275661      1276097           NaN
# mean                      NaN        NaN          NaN  1.214608e+01
# std                       NaN        NaN          NaN  7.516526e+00
# min                       NaN        NaN          NaN  0.000000e+00
# 25%                       NaN        NaN          NaN  8.000000e+00
# 50%                       NaN        NaN          NaN  1.100000e+01
# 75%                       NaN        NaN          NaN  1.500000e+01
# max                       NaN        NaN          NaN  9.800000e+01
#
#        COD_GENERO GRUPO_ETNICO SECTOR_CONPES  TOTAL_MATRICULA
# count     1425959      1367687       1425959     1.425959e+06
# unique          2            9             4              NaN
# top             M    No aplica       OFICIAL              NaN
# freq       750625      1217453       1168326              NaN
# mean          NaN          NaN           NaN     3.667568e+00
# std           NaN          NaN           NaN     5.909864e+00
# min           NaN          NaN           NaN     0.000000e+00
# 25%           NaN          NaN           NaN     1.000000e+00
# 50%           NaN          NaN           NaN     2.000000e+00
# 75%           NaN          NaN           NaN     4.000000e+00
# max           NaN          NaN           NaN     9.670000e+02

# %%
data_2010_2021.shape
# Out:
# (1425959, 19)

# %% [markdown]
# ### Se observa que tenemos 1.425.959 registros con 19 columnas

# %%
data_2010_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1425959 entries, 0 to 444434
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   ANNO_INF                1425959 non-null  int64
#  1   DEPARTAMENTO            1425959 non-null  object
#  2   SECRETARIA              1425959 non-null  object
#  3   MUNICIPIO               1425959 non-null  object
#  4   NOMBRE_ESTABLECIMIENTO  1403982 non-null  object
#  5   SECTOR                  1425959 non-null  object
#  6   CALENDARIO              1384657 non-null  object
#  7   NOMBRE_SEDE             1277065 non-null  object
#  8   ZONA                    1425959 non-null  object
#  9   TIPO_JORNADA            1425959 non-null  object
#  10  GRADO                   1425959 non-null  object
#  11  METODOLOGIA             1418188 non-null  object
#  12  CARACTER                1384657 non-null  object
#  13  ESPECIALIDAD            1384657 non-null  object
#  14  EDAD                    1425959 non-null  int64
#  15  COD_GENERO              1425959 non-null  object
#  16  GRUPO_ETNICO            1367687 non-null  object
#  17  SECTOR_CONPES           1425959 non-null  object
#  18  TOTAL_MATRICULA         1425959 non-null  int64
# dtypes: int64(3), object(16)
# memory usage: 217.6+ MB

# %% [markdown]
# ### Ahora con nuestro dataset conlumnas borradas de ve claramente que hay algunas columnas con datos faltantes o nulos

# %%
data_2010_2021.dropna(inplace=True)
# Borramos datos nulos

# %%
data_2010_2021.isna().sum()
# Out:
# ANNO_INF                  0
# DEPARTAMENTO              0
# SECRETARIA                0
# MUNICIPIO                 0
# NOMBRE_ESTABLECIMIENTO    0
# SECTOR                    0
# CALENDARIO                0
# NOMBRE_SEDE               0
# ZONA                      0
# TIPO_JORNADA              0
# GRADO                     0
# METODOLOGIA               0
# CARACTER                  0
# ESPECIALIDAD              0
# EDAD                      0
# COD_GENERO                0
# GRUPO_ETNICO              0
# SECTOR_CONPES             0
# TOTAL_MATRICULA           0
# dtype: int64

# %%
data_2010_2021.head()
# Out:
#    ANNO_INF DEPARTAMENTO SECRETARIA MUNICIPIO NOMBRE_ESTABLECIMIENTO   SECTOR  \
# 0      2017      Córdoba     Lorica    Lorica            IE EL RODEO  OFICIAL
# 1      2017      Córdoba     Lorica    Lorica        IE SAN ANTERITO  OFICIAL
# 2      2017      Córdoba     Lorica    Lorica           IE EL CARITO  OFICIAL
# 3      2017      Córdoba     Lorica    Lorica           IE EL CARITO  OFICIAL
# 4      2017      Córdoba     Lorica    Lorica          IE SANTA CRUZ  OFICIAL
#
#   CALENDARIO    NOMBRE_SEDE    ZONA TIPO_JORNADA   GRADO  \
# 0          A       LA BUENA   Rural       Mañana  Cuarto
# 1          A     LA ENVIDIA   Rural       Mañana  Cuarto
# 2          A      EL CARITO   Rural        Tarde  Quinto
# 3          A      EL CARITO   Rural        Tarde  Quinto
# 4          A  IE SANTA CRUZ  Urbana        Tarde  Quinto
#
#              METODOLOGIA   CARACTER ESPECIALIDAD  EDAD COD_GENERO  \
# 0  Educación tradicional  No Aplica    No aplica     8          F
# 1  Educación tradicional  No Aplica    No aplica     8          F
# 2  Educación tradicional  No Aplica    No aplica     9          F
# 3  Educación tradicional  No Aplica    No aplica     9          M
# 4  Educación tradicional  No Aplica    No aplica    12          M
#
#   GRUPO_ETNICO SECTOR_CONPES  TOTAL_MATRICULA
# 0    No aplica       OFICIAL                3
# 1    No aplica       OFICIAL                1
# 2    No aplica       OFICIAL                3
# 3    No aplica       OFICIAL                2
# 4    No aplica       OFICIAL                3

# %%
data_2010_2021["MUNICIPIO"].unique()
# Como se observa, en tenemos los municipios duplicados a razón de que unos están escritos en mayusculas
# Out:
# array(['Lorica', 'Cotorra', 'Cienaga De Oro', 'Puerto Escondido',
#        'Purísima', 'Tierralta', 'Chinu', 'Pueblo Nuevo', 'San Antero',
#        'Buenavista', 'Montelíbano', 'Canalete', 'Puerto Libertador',
#        'Planeta Rica', 'Chimá', 'San Andrés de Sotavento', 'San Pelayo',
#        'San Carlos', 'San Bernardo Del Viento', 'Moñitos', 'Ayapel',
#        'Cerete', 'Los Córdobas', 'Montería', 'Valencia',
#        'San José de Uré', 'Sahagún', 'Momil', 'La Apartada', 'Tuchín',
#        'MOÑITOS', 'MONTELÍBANO', 'LOS CÓRDOBAS', 'MOMIL',
#        'CIENAGA DE ORO', 'CHINU', 'CHIMÁ', 'LORICA', 'AYAPEL',
#        'SAN ANTERO', 'BUENAVISTA', 'CANALETE', 'SAHAGÚN', 'CERETE',
#        'MONTERÍA', 'TIERRALTA', 'PLANETA RICA', 'VALENCIA',
#        'PUEBLO NUEVO', 'SAN ANDRÉS DE SOTAVENTO', 'SAN CARLOS',
#        'PUERTO ESCONDIDO', 'SAN PELAYO', 'TUCHÍN', 'SAN JOSÉ DE URÉ',
#        'LA APARTADA', 'COTORRA', 'PUERTO LIBERTADOR',
#        'SAN BERNARDO DEL VIENTO', 'PURÍSIMA'], dtype=object)

# %%
# Procedemos a convertir los nombres de tal manera que coincidan y lo haremos con str.capitalize()
data_2010_2021["MUNICIPIO"] = data_2010_2021["MUNICIPIO"].str.capitalize()

# %%
data_2010_2021["MUNICIPIO"].unique().shape
# Y de esta forma tendriamos los nombres de los municipios estandarizados
# Out:
# (30,)

# %%
data_2010_2021["NOMBRE_ESTABLECIMIENTO"]
# Out:
# 0                                            IE EL RODEO
# 1                                        IE SAN ANTERITO
# 2                                           IE EL CARITO
# 3                                           IE EL CARITO
# 4                                          IE SANTA CRUZ
#                                ...
# 424487                       INSTITUCION EDUCATIVA JUNIN
# 424488                 INSTITUCION EDUCATIVA CAMINO REAL
# 424489         CENTRO EDUCATIVO FRANCISCO JOSE DE CALDAS
# 424490                   INSTITUCION EDUCATIVA EL CARMEN
# 424491    INSTITUCION EDUCATIVA FRANCISCO JOSE DE CALDAS
# Name: NOMBRE_ESTABLECIMIENTO, Length: 1177622, dtype: object

# %%
data_2010_2021["METODOLOGIA"].unique()
# Out:
# array(['Educación tradicional', 'Escuela nueva', 'Post primaria',
#        'Programa para jóvenes en extraedad y adultos', 'Crecer',
#        'Etnoeducación', 'Telesecundaria',
#        'Modelo Ser Humano (CICLO 1, 2, 3, 4, 5,6)',
#        'Aceleración del aprendizaje', 'Preescolar escolarizado',
#        'Media rural', 'Modalidad virtual asistida ucn', 'Espere', 'Sat',
#        'Grupos juveniles creativos', 'Cafam', 'Transformemos',
#        'Circulos de aprendizaje', 'Sat presencial', 'Ser',
#        'Preescolar no escolarizado/semiescolarizado',
#        'Caminar en Secundaria'], dtype=object)

# %%
data_2010_2021.groupby("GRUPO_ETNICO")["TOTAL_MATRICULA"].count().plot(kind="bar")
# Se observa que la cantidad total de matriculados está en un rango aprox de entre 0 a 100
# Out:
# <AxesSubplot:xlabel='GRUPO_ETNICO'>

# %%
plot = (100 * data_2010_2021["CALENDARIO"].value_counts() / len(data_2010_2021["CALENDARIO"])).plot(kind="bar");

# %%
sns.boxplot(y=data_2010_2021["TOTAL_MATRICULA"]);

# %%
data_2010_2021.head()
# Out:
#    ANNO_INF DEPARTAMENTO SECRETARIA MUNICIPIO NOMBRE_ESTABLECIMIENTO   SECTOR  \
# 0      2017      Córdoba     Lorica    Lorica            IE EL RODEO  OFICIAL
# 1      2017      Córdoba     Lorica    Lorica        IE SAN ANTERITO  OFICIAL
# 2      2017      Córdoba     Lorica    Lorica           IE EL CARITO  OFICIAL
# 3      2017      Córdoba     Lorica    Lorica           IE EL CARITO  OFICIAL
# 4      2017      Córdoba     Lorica    Lorica          IE SANTA CRUZ  OFICIAL
#
#   CALENDARIO    NOMBRE_SEDE    ZONA TIPO_JORNADA   GRADO  \
# 0          A       LA BUENA   Rural       Mañana  Cuarto
# 1          A     LA ENVIDIA   Rural       Mañana  Cuarto
# 2          A      EL CARITO   Rural        Tarde  Quinto
# 3          A      EL CARITO   Rural        Tarde  Quinto
# 4          A  IE SANTA CRUZ  Urbana        Tarde  Quinto
#
#              METODOLOGIA   CARACTER ESPECIALIDAD  EDAD COD_GENERO  \
# 0  Educación tradicional  No Aplica    No aplica     8          F
# 1  Educación tradicional  No Aplica    No aplica     8          F
# 2  Educación tradicional  No Aplica    No aplica     9          F
# 3  Educación tradicional  No Aplica    No aplica     9          M
# 4  Educación tradicional  No Aplica    No aplica    12          M
#
#   GRUPO_ETNICO SECTOR_CONPES  TOTAL_MATRICULA
# 0    No aplica       OFICIAL                3
# 1    No aplica       OFICIAL                1
# 2    No aplica       OFICIAL                3
# 3    No aplica       OFICIAL                2
# 4    No aplica       OFICIAL                3

# %%
data_2010_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1177622 entries, 0 to 424491
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   ANNO_INF                1177622 non-null  int64
#  1   DEPARTAMENTO            1177622 non-null  object
#  2   SECRETARIA              1177622 non-null  object
#  3   MUNICIPIO               1177622 non-null  object
#  4   NOMBRE_ESTABLECIMIENTO  1177622 non-null  object
#  5   SECTOR                  1177622 non-null  object
#  6   CALENDARIO              1177622 non-null  object
#  7   NOMBRE_SEDE             1177622 non-null  object
#  8   ZONA                    1177622 non-null  object
#  9   TIPO_JORNADA            1177622 non-null  object
#  10  GRADO                   1177622 non-null  object
#  11  METODOLOGIA             1177622 non-null  object
#  12  CARACTER                1177622 non-null  object
#  13  ESPECIALIDAD            1177622 non-null  object
#  14  EDAD                    1177622 non-null  int64
#  15  COD_GENERO              1177622 non-null  object
#  16  GRUPO_ETNICO            1177622 non-null  object
#  17  SECTOR_CONPES           1177622 non-null  object
#  18  TOTAL_MATRICULA         1177622 non-null  int64
# dtypes: int64(3), object(16)
# memory usage: 179.7+ MB

# %%
data_2010_2021.describe(include="O")
# Out:
#        DEPARTAMENTO SECRETARIA MUNICIPIO        NOMBRE_ESTABLECIMIENTO  \
# count       1177622    1177622   1177622                       1177622
# unique            2          8        30                          1247
# top         Córdoba    Córdoba  Montería  INST. EDUC. JULIO C. MIRANDA
# freq         797674     563071    212863                          7142
#
#          SECTOR CALENDARIO    NOMBRE_SEDE     ZONA TIPO_JORNADA    GRADO  \
# count   1177622    1177622        1177622  1177622      1177622  1177622
# unique        2          2           2698        2            6       24
# top     OFICIAL          A  IE SANTA CRUZ    Rural       Mañana  Tercero
# freq    1114023    1176967           4277   790153       786246   130186
#
#                   METODOLOGIA   CARACTER ESPECIALIDAD COD_GENERO GRUPO_ETNICO  \
# count                 1177622    1177622      1177622    1177622      1177622
# unique                     22          4            8          2            9
# top     Educación tradicional  No Aplica    No aplica          M    No aplica
# freq                   830280    1085693      1086129     621079      1048440
#
#        SECTOR_CONPES
# count        1177622
# unique             4
# top          OFICIAL
# freq         1002519

# %%
data_2010_2021["DEPARTAMENTO"] = data_2010_2021["DEPARTAMENTO"].str.capitalize()

# %%
data_2010_2021 = data_2010_2021.set_index("ANNO_INF")

# %%
data_2010_2021.head()
# Out:
#          DEPARTAMENTO SECRETARIA MUNICIPIO NOMBRE_ESTABLECIMIENTO   SECTOR  \
# ANNO_INF
# 2017          Córdoba     Lorica    Lorica            IE EL RODEO  OFICIAL
# 2017          Córdoba     Lorica    Lorica        IE SAN ANTERITO  OFICIAL
# 2017          Córdoba     Lorica    Lorica           IE EL CARITO  OFICIAL
# 2017          Córdoba     Lorica    Lorica           IE EL CARITO  OFICIAL
# 2017          Córdoba     Lorica    Lorica          IE SANTA CRUZ  OFICIAL
#
#          CALENDARIO    NOMBRE_SEDE    ZONA TIPO_JORNADA   GRADO  \
# ANNO_INF
# 2017              A       LA BUENA   Rural       Mañana  Cuarto
# 2017              A     LA ENVIDIA   Rural       Mañana  Cuarto
# 2017              A      EL CARITO   Rural        Tarde  Quinto
# 2017              A      EL CARITO   Rural        Tarde  Quinto
# 2017              A  IE SANTA CRUZ  Urbana        Tarde  Quinto
#
#                     METODOLOGIA   CARACTER ESPECIALIDAD  EDAD COD_GENERO  \
# ANNO_INF
# 2017      Educación tradicional  No Aplica    No aplica     8          F
# 2017      Educación tradicional  No Aplica    No aplica     8          F
# 2017      Educación tradicional  No Aplica    No aplica     9          F
# 2017      Educación tradicional  No Aplica    No aplica     9          M
# 2017      Educación tradicional  No Aplica    No aplica    12          M
#
#          GRUPO_ETNICO SECTOR_CONPES  TOTAL_MATRICULA
# ANNO_INF
# 2017        No aplica       OFICIAL                3
# 2017        No aplica       OFICIAL                1
# 2017        No aplica       OFICIAL                3
# 2017        No aplica       OFICIAL                2
# 2017        No aplica       OFICIAL                3

# %%
data_2010_2021["METODOLOGIA"].unique()
# Out:
# array(['Educación tradicional', 'Escuela nueva', 'Post primaria',
#        'Programa para jóvenes en extraedad y adultos', 'Crecer',
#        'Etnoeducación', 'Telesecundaria',
#        'Modelo Ser Humano (CICLO 1, 2, 3, 4, 5,6)',
#        'Aceleración del aprendizaje', 'Preescolar escolarizado',
#        'Media rural', 'Modalidad virtual asistida ucn', 'Espere', 'Sat',
#        'Grupos juveniles creativos', 'Cafam', 'Transformemos',
#        'Circulos de aprendizaje', 'Sat presencial', 'Ser',
#        'Preescolar no escolarizado/semiescolarizado',
#        'Caminar en Secundaria'], dtype=object)

# %%
data_2010_2021["TIPO_JORNADA"].unique()
# Out:
# array(['Mañana', 'Tarde', 'Unica', 'Completa', 'Fin de Semana',
#        'Nocturna'], dtype=object)

# %%
jornada_mañana = data_2010_2021["TOTAL_MATRICULA"][(data_2010_2021["TIPO_JORNADA"] == 'Mañana')].count()
jornada_tarde = data_2010_2021["TOTAL_MATRICULA"][(data_2010_2021["TIPO_JORNADA"] == 'Tarde')].count()
jornada_Unica = data_2010_2021["TOTAL_MATRICULA"][(data_2010_2021["TIPO_JORNADA"] == 'Unica')].count()
jornada_completa = data_2010_2021["TOTAL_MATRICULA"][(data_2010_2021["TIPO_JORNADA"] == 'Completa')].count()
jornada_finsemana = data_2010_2021["TOTAL_MATRICULA"][(data_2010_2021["TIPO_JORNADA"] == 'Fin de Semana')].count()
jornada_Nocturna = data_2010_2021["TOTAL_MATRICULA"][(data_2010_2021["TIPO_JORNADA"] == 'Nocturna')].count()

lista = [jornada_mañana, jornada_tarde, jornada_Unica, jornada_completa, jornada_completa, jornada_finsemana, jornada_Nocturna]

# %%
f_o_m = data_2010_2021["COD_GENERO"].groupby(data_2010_2021["COD_GENERO"]).count()
cod_gender = ["F", "M"]
plt.pie(f_o_m, labels=cod_gender, autopct="%.1f%%")
plt.show();

# %% [markdown]
# ### Graficamente se observa que desde el 2010 al 2021 un 52.6% del total de matriculados son masculinos y el 47.4% es del genero femenino

# %%
edad = data_2010_2021.groupby(["EDAD"])["TOTAL_MATRICULA"].count()

edad_ord = np.sort(data_2010_2021["EDAD"].unique())
fig, ax = plt.subplots(figsize=(12, 6))
plt.xticks(rotation="90")
sns.barplot(x = edad_ord, y = edad)
plt.xlabel("AÑOS")
plt.ylabel("CANTIDAD MATRICULADOS")
plt.title("CANTIDAD DE ESTUDIANTES MATRICULADOS POR AÑOS");

# %%
data_2010_2021["EDAD"].min()
# Out:
# 0

# %% [markdown]
# #### Podemos observar que las personas matriculadas en su mayoria están en un rango de edad aprox. de entre (2 a 20 años)

# %% [markdown]
# ### Analisis de la cantidad de estudiantes matriculados por años
# ### Se observa que en el año 2015 hubo un gran incrementro de estudiantes matriculadod en el departamento de Córdoba

# %%
annios = data_2010_2021.groupby([data_2010_2021.index])["TOTAL_MATRICULA"].count()

annios_ord = np.sort(data_2010_2021.index.unique())
fig, ax = plt.subplots(figsize=(10, 4))
plt.xticks(rotation="90")
sns.barplot(x = annios_ord, y = annios)
plt.xlabel("AÑOS")
plt.ylabel("CANTIDAD MATRICULADOS")
plt.title("CANTIDAD DE ESTUDIANTES MATRICULADOS POR AÑOS");

# %%
cantidad_matriculas_zonas = data_2010_2021.groupby(["MUNICIPIO"])[["TOTAL_MATRICULA"]].count()
cantidad = cantidad_matriculas_zonas["TOTAL_MATRICULA"].unique()

municipios = np.sort(data_2010_2021["MUNICIPIO"].unique())
fig, ax = plt.subplots(figsize=(10, 4))
plt.xticks(rotation="90")
sns.barplot(x = municipios, y = cantidad)
plt.xlabel("MUNICIPIOS")
plt.ylabel("CANTIDAD MATRICULADOS")
plt.title("CANTIDAD DE ESTUDIANTES MATRICULADOS POR MUNICIPIOS");

# %% [markdown]
# ### Analisis de la cantidad de estudiantes matriculados en zona rural y urbana

# %%
cantidad_matriculas_zonas = data_2010_2021.groupby(["ZONA"])[["TOTAL_MATRICULA"]].count()
cantidad_matriculados = cantidad_matriculas_zonas["TOTAL_MATRICULA"].unique()

zonas = np.sort(data_2010_2021["ZONA"].unique())
fig, ax = plt.subplots(figsize=(8, 4))
plt.xticks(rotation="90")
sns.barplot(x = zonas, y = cantidad_matriculados)
plt.xlabel("ZONAS")
plt.ylabel("CANTIDAD MATRICULADOS")
plt.title("CANTIDAD DE ESTUDIANTES MATRICULADOS POR POR ZONAS");

# %%
cant = cantidad_matriculas_zonas = data_2010_2021.groupby(["ZONA"])["TOTAL_MATRICULA"].count()
cant
# Out:
# ZONA
# Rural     790153
# Urbana    387469
# Name: TOTAL_MATRICULA, dtype: int64
